# %% [markdown]
# ## Load segments from Slicer

# %%
import numpy
import sys
import os
import matplotlib.pyplot as plt
# import skimage
import nrrd
from scipy import ndimage

sys.path.insert(0, "../src")  # add Folder_2 path to search list

from meshing_functions import getSurfaceMesh, tetra_mesh_from_stl


base = "/Users/skardova/Documents/MRI_data/2026-Eyes-project/Trial2/cropped T1/segmentations/"
in_folder = "segmentations/optical nerve and eyeball/and muscle/"    

out_folder = "Meshes/"
# Out:
# pixel spacing =  [0.3125 0.3125 0.5   ]
# id =  4
# dimensions =  (145, 209, 101)
# dimensions =  (145, 209, 162)
# id =  4
